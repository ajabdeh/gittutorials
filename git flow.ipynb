# %% [markdown]
# ### 1. Create repository from github.

# %% [markdown]
# ### 2. check version of git
#
# **git --version**

# %% [markdown]
# ### 3. setup an user
# **git config --global user.name "ajabdeh"**

# %% [markdown]
# ### 4. setup an email
# **git config --global user.email "abc@gmail.com"**

# %% [markdown]
# ### 5. initialize git
# **git init**

# %% [markdown]
# ### 6. add new file
# **git add README.md**

# %% [markdown]
# ### 7. add new files & other versioned files
# **git add .**

# %% [markdown]
# ## 8. commit
# **git commit -m "1st commit"**

# %% [markdown]
# ### add & commit if there is no unversioned file
# **git commit -a -m "2nd commit"**

# %% [markdown]
# # git status

# %% [markdown]
# Git replies with a summary of your repo’s state.

# %% [markdown]
# ![image.png](attachment:a24ff0dd-25c0-43d1-82b4-147c6dcfddbd.png)

# %% [markdown]
# ![image.png](attachment:025979a2-5f70-4f8f-b234-ef8811c28c06.png)

# %% [markdown]
# # 🛠️ What Other Outputs Can Look Like:

# %% [markdown]
# ## 1. Modified but not staged

# %% [markdown]
# ![image.png](attachment:7ef7aed0-61d8-4b80-984e-e4f3d12386a9.png)

# %% [markdown]
# ## 2. New files (untracked)

# %% [markdown]
# ![image.png](attachment:332f4223-8374-4ce7-8172-936413a3246d.png)

# %% [markdown]
# ## 3. Files staged for commit

# %% [markdown]
# ![image.png](attachment:1c23d256-dc3f-41f6-a22e-b2f9ee60c956.png)

# %% [markdown]
# ![image.png](attachment:7e71556e-e717-49fa-a64f-f9ddf5546349.png)

# %% [markdown]
# ### 9. change branch name to main
# git branch -m main

# %% [markdown]
# ### 10. connect local repo to git repo
# git remote add origin [url]

# %% [markdown]
# ### 11. git push from origin to main

# %% [markdown]
# **🧾 git push origin main**
# * Pushes your local main branch to the main branch on origin (usually GitHub).
#
# * Does not set any tracking relationship.
#
# *  Next time you push or pull, you must specify the remote and branch again.

# %% [markdown]
# **🧙 git push -u origin main (or --set-upstream)**
# * Pushes your local main branch to origin/main.
#
# * AND tells Git:
#
# "From now on, when I’m on main, and I type just git push or git pull, I mean origin/main."

# %% [markdown]
# # git restore filename

# %% [markdown]
# ## 🛠️ Common Use Cases

# %% [markdown]
# ![image.png](attachment:a968f6bd-c7ec-4ad8-ad4f-e17f43d64eba.png)

# %% [markdown]
# ![image.png](attachment:17d286d7-acba-4b30-a847-ad228712156c.png)

# %% [markdown]
# ![image.png](attachment:0b382744-d932-4aa7-80ad-992f501662ab.png)

# %% [markdown]
# ![image.png](attachment:5338f4ee-f3e8-4804-98a7-731493039af0.png)

# %% [markdown]
# # git remote -v

# %% [markdown]
# ![image.png](attachment:4f04e0ef-6468-4f1d-acd2-ad5f3a11d169.png)

# %% [markdown]
# ![image.png](attachment:1b586157-e35e-43ee-b3b3-4ab7aa67b65c.png)

# %% [markdown]
# ![image.png](attachment:3e1ee82f-3ddb-4008-8320-5df421de8cab.png)

# %% [markdown]
# ![image.png](attachment:de5ff2c7-12d3-4880-b93c-e7d6caa658af.png)

# %% [markdown]
# **git clone [url]**

# %% [markdown]
# ![image.png](attachment:3ea8cf80-1c89-401b-93f0-edba190e44be.png)

# %% [markdown]
# ![image.png](attachment:28de14c6-6e34-4218-98e7-8f1d4e5c5c2f.png)

# %% [markdown]
# ![image.png](attachment:178db75a-d9b1-4331-844d-d513da75a1fe.png)
